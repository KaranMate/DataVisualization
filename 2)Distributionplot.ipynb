# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset('tips')  #inbulid datasate
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.size
# Out:
# 1708

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
df.count()
# Out:
# total_bill    244
# tip           244
# sex           244
# smoker        244
# day           244
# time          244
# size          244
# dtype: int64

# %%
sns.displot(df['total_bill'],bins=19,kde=True) 
#with the help of bins you can decide in how much line you want to split the data
#with the help of kde the lines are shown on graph

# %%
sns.histplot(df['sex']) #you can  use all the variable mension in table
# both histplot and displot do the same work
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
plt.subplot(1,2,1)
sns.histplot(df['total_bill'],bins=18 ,kde=True)
plt.subplot(1,2,2)
sns.histplot(df['tip'],bins=18 ,kde=True)


#we can use both seaborn and matplotlips but in graps seaborn properties work
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
#JOIN PLOT

# %%
sns.jointplot(x='total_bill' ,y='tip',data=df,kind='scatter')

# %%
sns.jointplot(x='total_bill' ,y='tip',data=df,kind='kde')
# their are multiple parameters in kind if you want to use it click (shift+Tab)

# %% [markdown]
# Pair plor
# (Important plot amoung all of them )

# %%
sns.pairplot(df,hue='size', palette='rainbow')
#pair compair all the data
#hue segerate the  data and split in different form to match the data
#palette is use to put different shades of color user want

# %% [markdown]
# Rugplot

# %%
sns.rugplot(df)
# Out:
# <Axes: >
