# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# HEAT MAP
#
# CLUSTER MAP
#
# Pivort Table Heat Mape

# %%
#HEAT MAP

# %%
flights=sns.load_dataset('flights')
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tipscorr=tips[['total_bill','size','tip']]
tipscorr
# Out:
#      total_bill  size   tip
# 0         16.99     2  1.01
# 1         10.34     3  1.66
# 2         21.01     3  3.50
# 3         23.68     2  3.31
# 4         24.59     4  3.61
# ..          ...   ...   ...
# 239       29.03     3  5.92
# 240       27.18     2  2.00
# 241       22.67     2  2.00
# 242       17.82     2  1.75
# 243       18.78     2  3.00
#
# [244 rows x 3 columns]

# %%
tipscorr.corr() 
#first we also add smoker in the table but we cannot add string and integer together so we cancel it
# Out:
#             total_bill      size       tip
# total_bill    1.000000  0.598315  0.675734
# size          0.598315  1.000000  0.489299
# tip           0.675734  0.489299  1.000000

# %%
sns.heatmap(tipscorr.corr(),annot=True,robust=True)
# Out:
# <Axes: >

# %%
#CLUSTER MAP

# %%
sns.clustermap(tipscorr.corr(),annot=True,row_cluster=True)

# %%
#Pivot Table and HeAT Map

# %%
pvtflight=flights.pivot_table(values='passengers',index='year',columns='month')
# Out:
# C:\Users\Karan\AppData\Local\Temp\ipykernel_18556\1115790829.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pvtflight=flights.pivot_table(values='passengers',index='year',columns='month')

# %%
pvtflight
# Out:
# month    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep    Oct  \
# year
# 1949   112.0  118.0  132.0  129.0  121.0  135.0  148.0  148.0  136.0  119.0
# 1950   115.0  126.0  141.0  135.0  125.0  149.0  170.0  170.0  158.0  133.0
# 1951   145.0  150.0  178.0  163.0  172.0  178.0  199.0  199.0  184.0  162.0
# 1952   171.0  180.0  193.0  181.0  183.0  218.0  230.0  242.0  209.0  191.0
# 1953   196.0  196.0  236.0  235.0  229.0  243.0  264.0  272.0  237.0  211.0
# 1954   204.0  188.0  235.0  227.0  234.0  264.0  302.0  293.0  259.0  229.0
# 1955   242.0  233.0  267.0  269.0  270.0  315.0  364.0  347.0  312.0  274.0
# 1956   284.0  277.0  317.0  313.0  318.0  374.0  413.0  405.0  355.0  306.0
# 1957   315.0  301.0  356.0  348.0  355.0  422.0  465.0  467.0  404.0  347.0
# 1958   340.0  318.0  362.0  348.0  363.0  435.0  491.0  505.0  404.0  359.0
# 1959   360.0  342.0  406.0  396.0  420.0  472.0  548.0  559.0  463.0  407.0
# ...

# %%
 sns.heatmap(pvtflight,palette)
# Out:
# <Axes: xlabel='month', ylabel='year'>
